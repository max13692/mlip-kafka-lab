# %% [markdown]
# # Kafka Demo
#
# ### Connect to Kafka Broker Server
# ```
# ssh -o ServerAliveInterval=60 -L 9092:localhost:9092 tunnel@128.2.204.215 -NTf
# ```
# pass: seaitunnel
#
#
# To kill connection at port:
# ```
# lsof -ti:9092 | xargs kill -9
# ```
#
# ### Setup
# ```
# python -m pip install kafka-python
# ```

# %%
from os import path
import sys, os
from datetime import datetime
from json import dumps, loads
from time import sleep
from random import randint
import numpy as np
# ssh -o ServerAliveInterval=60 -L 9092:localhost:9092 tunnel@128.2.24.106 -NTf
from kafka import KafkaConsumer, KafkaProducer

# Update this for your own recitation section :)
topic = 'recitation-a'

# %% [markdown]
# ### Producer Mode -> Writes Data to Broker

# %%
# Create a producer to write data to kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaProducer.html

# [TODO]: Replace '...' with the address of your Kafka bootstrap server
producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                         value_serializer=lambda x: dumps(x).encode('utf-8'))


# [TODO]: Add cities of your choice
cities = ['New York', 'London', 'Tokyo', 'Paris', 'Sydney']

# Write data via the producer
print("Writing to Kafka Broker")
for i in range(10):
    data = f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")},{cities[randint(0,len(cities)-1)]},{randint(18, 32)}ºC'
    print(f"Writing: {data}")
    producer.send(topic=topic, value=data)
    sleep(1)
# Out:
# Writing to Kafka Broker
# Writing: 2024-01-25 21:02:35,Sydney,30ºC
# Writing: 2024-01-25 21:02:36,Tokyo,31ºC
# Writing: 2024-01-25 21:02:36,Tokyo,21ºC
# Writing: 2024-01-25 21:02:36,Sydney,31ºC
# Writing: 2024-01-25 21:02:36,London,25ºC
# Writing: 2024-01-25 21:02:36,Tokyo,29ºC
# Writing: 2024-01-25 21:02:36,Paris,19ºC
# Writing: 2024-01-25 21:02:36,Tokyo,24ºC
# Writing: 2024-01-25 21:02:36,Sydney,27ºC
# Writing: 2024-01-25 21:02:36,Sydney,28ºC
# Writing: 2024-01-25 21:02:36,Paris,32ºC
# Writing: 2024-01-25 21:02:37,New York,28ºC
# Writing: 2024-01-25 21:02:37,London,31ºC
# Writing: 2024-01-25 21:02:37,Paris,28ºC
# Writing: 2024-01-25 21:02:37,Sydney,22ºC
# Writing: 2024-01-25 21:02:37,Tokyo,28ºC
# Writing: 2024-01-25 21:02:37,New York,26ºC
# Writing: 2024-01-25 21:02:37,London,18ºC
# Writing: 2024-01-25 21:02:37,New York,18ºC
# Writing: 2024-01-25 21:02:37,Paris,18ºC
# Writing: 2024-01-25 21:02:37,London,27ºC
# Writing: 2024-01-25 21:02:38,London,29ºC
# Writing: 2024-01-25 21:02:38,Sydney,32ºC
# Writing: 2024-01-25 21:02:38,Paris,25ºC
# Writing: 2024-01-25 21:02:38,Sydney,22ºC
# Writing: 2024-01-25 21:02:38,London,27ºC
# Writing: 2024-01-25 21:02:38,Sydney,22ºC
# Writing: 2024-01-25 21:02:38,Tokyo,19ºC
# Writing: 2024-01-25 21:02:38,New York,32ºC
# Writing: 2024-01-25 21:02:38,Tokyo,20ºC
# Writing: 2024-01-25 21:02:38,Tokyo,21ºC
# Writing: 2024-01-25 21:02:39,Sydney,30ºC
# Writing: 2024-01-25 21:02:39,Sydney,19ºC
# Writing: 2024-01-25 21:02:39,Tokyo,21ºC
# Writing: 2024-01-25 21:02:39,New York,32ºC
# Writing: 2024-01-25 21:02:39,Paris,24ºC
# Writing: 2024-01-25 21:02:39,Tokyo,26ºC
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Consumer Mode -> Reads Data from Broker

# %%
# Create a consumer to read data from kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaConsumer.html

# [TODO]: Complete the missing ... parameters/arguments using the Kafka documentation
consumer = KafkaConsumer(
    topic,
    bootstrap_servers=['localhost:9092'],
    auto_offset_reset='earliest', #Experiment with different values
    # Commit that an offset has been read
    enable_auto_commit=True,
    # How often to tell Kafka, an offset has been read
    auto_commit_interval_ms=1000
)

print('Reading Kafka Broker')
for message in consumer:

    message = message.value.decode()
    # Default message.value type is bytes!
    print(loads(message))
    os.system(f"echo {message} >> kafka_log.csv")
# Out:
# Reading Kafka Broker
# 2024-01-24 22:17:04,denver,28ºC
# 2024-01-24 22:17:05,minneapolis,18ºC
# 2024-01-24 22:17:06,minneapolis,32ºC
# 2024-01-24 22:17:07,denver,28ºC
# 2024-01-24 22:17:08,denver,26ºC
# 2024-01-24 22:17:09,minneapolis,18ºC
# 2024-01-24 22:17:10,denver,22ºC
# 2024-01-24 22:17:11,minneapolis,27ºC
# 2024-01-24 22:17:12,minneapolis,25ºC
# 2024-01-24 22:17:13,minneapolis,25ºC
# 2024-01-24 22:32:35,minneapolis,21ºC
# 2024-01-24 22:32:36,minneapolis,25ºC
# 2024-01-24 22:32:37,minneapolis,28ºC
# 2024-01-24 22:32:38,minneapolis,18ºC
# 2024-01-24 22:32:39,minneapolis,30ºC
# 2024-01-24 22:32:40,minneapolis,25ºC
# 2024-01-24 22:32:41,minneapolis,32ºC
# 2024-01-24 22:32:42,denver,22ºC
# 2024-01-24 22:32:43,minneapolis,21ºC
# 2024-01-24 22:32:44,denver,24ºC
# 2024-01-24 23:04:36,denver,20ºC
# 2024-01-24 23:04:37,denver,30ºC
# 2024-01-24 23:04:38,minneapolis,26ºC
# 2024-01-24 23:04:39,denver,19ºC
# 2024-01-24 23:04:40,minneapolis,25ºC
# 2024-01-24 23:04:41,minneapolis,20ºC
# 2024-01-24 23:04:42,minneapolis,25ºC
# 2024-01-24 23:04:43,denver,18ºC
# 2024-01-24 23:04:44,minneapolis,32ºC
# 2024-01-24 23:04:45,denver,30ºC
# 2024-01-25 20:59:14,Tokyo,21ºC
# 2024-01-25 20:59:15,New York,22ºC
# 2024-01-25 20:59:16,Tokyo,18ºC
# 2024-01-25 20:59:17,Tokyo,24ºC
# 2024-01-25 20:59:18,New York,24ºC
# 2024-01-25 20:59:19,Sydney,31ºC
# 2024-01-25 20:59:20,Paris,31ºC
# 2024-01-25 20:59:21,London,18ºC
# 2024-01-25 20:59:22,Paris,20ºC
# 2024-01-25 20:59:23,Paris,21ºC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 16
#       5 consumer = KafkaConsumer(
#       6     topic,
#       7     bootstrap_servers=['localhost:9092'],
#    (...)
#      12     auto_commit_interval_ms=1000
#      13 )
#      15 print('Reading Kafka Broker')
# ---> 16 for message in consumer:
#      18     message = message.value.decode()
#      19     # Default message.value type is bytes!
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/.local/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/.local/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /usr/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Use kcat!
# It's a CLI (Command Line Interface). Previously known as kafkacat
#
#
# Ref: https://docs.confluent.io/platform/current/app-development/kafkacat-usage.html

# %%
#kcat command: connect to local Kafka broker, specify a topic, and consume messages from the earliest offset

! kafkacat -b localhost:9092 -t recitation-a -C -o earliest
